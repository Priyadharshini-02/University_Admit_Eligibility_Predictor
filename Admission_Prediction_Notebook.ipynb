# %% [markdown]
# # **University Admit Eligibility Predictor**

# %% [markdown]
# ### **Description:**
#
# *Students are often worried about their chances of admission to University. The aim of this project is to help students in shortlisting universities with their profiles. The predicted output gives them a fair idea about their admission chances in a particular university. This analysis should also help students who are currently preparing or will be preparing to get a better idea.*

# %% [markdown]
# ## **Download and Load Dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as rcParams

# %%
df=pd.read_csv('Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df = pd.read_csv('Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df = df.rename(columns = {'GRE Score': 'GRE','TOEFL Score': 'TOEFL','University Rating': 'University_Rating','LOR ':'LOR',
                          'Chance of Admit ':'Admit_Chance'})
df.head()
# Out:
#    Serial No.  GRE  TOEFL  University_Rating  SOP  LOR  CGPA  Research  \
# 0           1  337    118                  4  4.5  4.5  9.65         1
# 1           2  324    107                  4  4.0  4.5  8.87         1
# 2           3  316    104                  3  3.0  3.5  8.00         1
# 3           4  322    110                  3  3.5  2.5  8.67         1
# 4           5  314    103                  2  2.0  3.0  8.21         0
#
#    Admit_Chance
# 0          0.92
# 1          0.76
# 2          0.72
# 3          0.80
# 4          0.65

# %%
df = df.drop(columns=['Serial No.'],axis=1)
df.head()
# Out:
#    GRE  TOEFL  University_Rating  SOP  LOR  CGPA  Research  Admit_Chance
# 0  337    118                  4  4.5  4.5  9.65         1          0.92
# 1  324    107                  4  4.0  4.5  8.87         1          0.76
# 2  316    104                  3  3.0  3.5  8.00         1          0.72
# 3  322    110                  3  3.5  2.5  8.67         1          0.80
# 4  314    103                  2  2.0  3.0  8.21         0          0.65

# %%
df.shape
# Out:
# (400, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE                400 non-null    int64
#  1   TOEFL              400 non-null    int64
#  2   University_Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Admit_Chance       400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
df.University_Rating.unique()
# Out:
# array([4, 3, 2, 5, 1])

# %%
df.SOP.unique()
# Out:
# array([4.5, 4. , 3. , 3.5, 2. , 5. , 1.5, 1. , 2.5])

# %%
df.LOR.unique()
# Out:
# array([4.5, 3.5, 2.5, 3. , 4. , 1.5, 2. , 5. , 1. ])

# %%
df.Research.value_counts()
# Out:
# 1    219
# 0    181
# Name: Research, dtype: int64

# %%
df.University_Rating.value_counts()
# Out:
# 3    133
# 2    107
# 4     74
# 5     60
# 1     26
# Name: University_Rating, dtype: int64

# %% [markdown]
# ## **Visualizations**

# %% [markdown]
#  **Univariate Analysis**

# %%
sns.displot(df.CGPA)

# %%
plt.pie(df.Research.value_counts(),[0,0.2],shadow='True',autopct="1%.1f%%")   #categorial column
# Out:
# ([<matplotlib.patches.Wedge at 0x7f334a298250>,
#   <matplotlib.patches.Wedge at 0x7f334a298c10>],
#  [Text(-0.1635397261721476, 1.087775141269343, ''),
#   Text(0.1932742218398109, -1.2855524396819509, '')],
#  [Text(-0.08920348700298959, 0.5933318952378234, '154.8%'),
#   Text(0.11893798267065285, -0.7911091936504312, '145.2%')])

# %%
sns.kdeplot(df.University_Rating,color="Green")

# %%
sns.countplot(df.GRE)
plt.title('GRE Score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'GRE Score')

# %% [markdown]
# **Bi-variate Analysis**

# %%
sns.jointplot(df.CGPA,df.Admit_Chance)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.GRE,df.Admit_Chance,color="Red")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df.SOP,df.LOR,color='Green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.bar(df.TOEFL,df.Admit_Chance)
# Out:
# <BarContainer object of 400 artists>

# %% [markdown]
# **Multi-variate Analysis**

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f33498345d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f334984abd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f33497ff210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f33497b1810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f33497e7e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f334972d450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3349764ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3349711b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f33496a8090>]],
#       dtype=object)

# %%
sns.pairplot(df,hue='Admit_Chance',diag_kind='kde')

# %%
sns.pairplot(data=df[['GRE','TOEFL','CGPA','Admit_Chance']],kind='kde')

# %% [markdown]
# ## **Descriptive statistics**

# %%
df.describe()
# Out:
#               GRE       TOEFL  University_Rating         SOP         LOR  \
# count  400.000000  400.000000         400.000000  400.000000  400.000000
# mean   316.807500  107.410000           3.087500    3.400000    3.452500
# std     11.473646    6.069514           1.143728    1.006869    0.898478
# min    290.000000   92.000000           1.000000    1.000000    1.000000
# 25%    308.000000  103.000000           2.000000    2.500000    3.000000
# 50%    317.000000  107.000000           3.000000    3.500000    3.500000
# 75%    325.000000  112.000000           4.000000    4.000000    4.000000
# max    340.000000  120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Admit_Chance
# count  400.000000  400.000000    400.000000
# mean     8.598925    0.547500      0.724350
# std      0.596317    0.498362      0.142609
# min      6.800000    0.000000      0.340000
# 25%      8.170000    0.000000      0.640000
# 50%      8.610000    1.000000      0.730000
# 75%      9.062500    1.000000      0.830000
# max      9.920000    1.000000      0.970000

# %% [markdown]
# ## **Handle missing data**

# %%
df.isnull().any() #There is no missing data in this dataset
# Out:
# GRE                  False
# TOEFL                False
# University_Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Admit_Chance         False
# dtype: bool

# %% [markdown]
# ## **Outliers Replacement**

# %%
sns.boxplot(df.GRE)   #This datset has no outliers
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## **Correlation**

# %%
df.corr()
# Out:
#                         GRE     TOEFL  University_Rating       SOP       LOR  \
# GRE                1.000000  0.835977           0.668976  0.612831  0.557555
# TOEFL              0.835977  1.000000           0.695590  0.657981  0.567721
# University_Rating  0.668976  0.695590           1.000000  0.734523  0.660123
# SOP                0.612831  0.657981           0.734523  1.000000  0.729593
# LOR                0.557555  0.567721           0.660123  0.729593  1.000000
# CGPA               0.833060  0.828417           0.746479  0.718144  0.670211
# Research           0.580391  0.489858           0.447783  0.444029  0.396859
# Admit_Chance       0.802610  0.791594           0.711250  0.675732  0.669889
#
#                        CGPA  Research  Admit_Chance
# GRE                0.833060  0.580391      0.802610
# TOEFL              0.828417  0.489858      0.791594
# University_Rating  0.746479  0.447783      0.711250
# SOP                0.718144  0.444029      0.675732
# LOR                0.670211  0.396859      0.669889
# CGPA               1.000000  0.521654      0.873289
# Research           0.521654  1.000000      0.553202
# Admit_Chance       0.873289  0.553202      1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.corr().Admit_Chance.sort_values(ascending=False)
# Out:
# Admit_Chance         1.000000
# CGPA                 0.873289
# GRE                  0.802610
# TOEFL                0.791594
# University_Rating    0.711250
# SOP                  0.675732
# LOR                  0.669889
# Research             0.553202
# Name: Admit_Chance, dtype: float64

# %% [markdown]
# ## **Split the data into dependent and independent variables**

# %%
#y - target columns
#X - predicting columns

# %%
y=df['Admit_Chance']
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Admit_Chance, Length: 400, dtype: float64

# %%
X=df.drop(columns=['Admit_Chance'],axis=1)
X.head()
# Out:
#    GRE  TOEFL  University_Rating  SOP  LOR  CGPA  Research
# 0  337    118                  4  4.5  4.5  9.65         1
# 1  324    107                  4  4.0  4.5  8.87         1
# 2  316    104                  3  3.0  3.5  8.00         1
# 3  322    110                  3  3.5  2.5  8.67         1
# 4  314    103                  2  2.0  3.0  8.21         0

# %% [markdown]
# ## **Split the data into training and testing**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=22)

# %%
X_train.shape,X_test.shape
# Out:
# ((280, 7), (120, 7))

# %%
y_train.shape,y_test.shape
# Out:
# ((280,), (120,))

# %% [markdown]
# ## **Build the model**

# %%
from sklearn.linear_model import Ridge
model=Ridge()                                 #Ridge Regression Model

# %% [markdown]
# ## **Train the model**

# %%
model.fit(X_train,y_train)
# Out:
# Ridge()

# %%
pred_train=model.predict(X_train)
pred_train
# Out:
# array([0.55820649, 0.69394121, 0.78490369, 0.64239651, 0.70986015,
#        0.71303264, 0.82663895, 0.59606548, 0.74701658, 0.81364823,
#        0.63546582, 0.5821777 , 0.84134889, 0.88258207, 0.82520152,
#        0.80816551, 0.93879824, 0.89768673, 0.84937251, 0.85458878,
#        0.74362344, 0.65460077, 0.76958428, 0.60457133, 0.83276012,
#        0.71441171, 0.71148696, 0.63242652, 0.46409762, 0.62349194,
#        0.62171344, 0.6858671 , 0.61477689, 0.81227191, 0.88880183,
#        0.96327592, 0.9986975 , 0.6108641 , 0.80832501, 0.90238771,
#        0.86050308, 0.61937646, 0.8540303 , 0.66430077, 0.70126845,
#        0.73558026, 0.51923568, 0.489815  , 0.67593288, 0.80336933,
#        0.72606227, 0.66069473, 0.95684019, 0.62667861, 0.82781486,
#        0.61422627, 0.72231992, 0.77504418, 0.57394348, 0.70641894,
#        0.94447751, 0.62646925, 0.96956154, 0.77306593, 0.51314191,
#        0.50436601, 0.65635717, 0.84307799, 0.72842273, 0.79702528,
#        0.80348722, 0.78682605, 0.72584572, 0.66295095, 0.58911461,
#        0.78335913, 0.51598803, 0.46299945, 0.67871323, 0.90905784,
#        0.57511019, 0.59947756, 0.68308737, 0.43491441, 0.77269863,
#        0.68031168, 0.76722957, 0.8823788 , 0.75072217, 0.65952223,
#        0.72505601, 0.58541807, 0.61300393, 0.73745815, 0.73962148,
#        0.75053539, 0.87022586, 0.64170795, 0.79667039, 0.73972133,
#        0.66948635, 0.51746226, 0.8493237 , 0.91069917, 0.57650118,
#        0.6922188 , 0.76462852, 0.77054366, 0.67547854, 0.54296054,
#        0.8991561 , 0.94081857, 0.68154563, 0.68288679, 0.6637096 ,
#        0.77977123, 0.71434696, 0.64804587, 0.64631936, 0.93914336,
#        0.54517008, 0.97799897, 0.49216882, 0.90267148, 0.55863409,
#        0.65361942, 0.77194162, 0.78096594, 0.93557024, 0.67661484,
#        0.83462123, 0.65670395, 0.66604703, 0.65813556, 0.84463246,
#        0.86971825, 0.78192295, 0.72167921, 0.95287838, 0.75149958,
#        0.76326953, 0.60732407, 0.88356069, 0.81468958, 0.8066281 ,
#        0.51912322, 0.74009256, 0.54557362, 0.95947828, 0.87909491,
#        0.48280955, 0.61373987, 0.70854069, 0.59723928, 0.65963807,
#        0.57929074, 0.55643746, 0.78091597, 0.69414583, 0.71488325,
#        0.63388733, 0.75564297, 0.89559812, 0.67496891, 0.80826839,
#        0.84009265, 0.84397525, 0.69011998, 0.46196157, 0.45692945,
#        0.73722074, 0.6705284 , 0.95386169, 0.711558  , 0.78829476,
#        0.53682306, 0.95908528, 0.67827548, 0.68861627, 0.8372644 ,
#        0.70259135, 0.82222907, 0.65787965, 0.8192152 , 0.82177911,
#        0.70680122, 0.98451761, 0.68367452, 0.80019961, 0.96950179,
#        0.96207089, 0.74181884, 0.61618954, 0.7249654 , 0.62395423,
#        0.69270367, 0.78951244, 0.77658119, 0.82111717, 0.63455619,
#        0.66501063, 0.92077314, 0.85635402, 0.84199975, 0.57312089,
#        0.55642041, 0.86654339, 0.54534486, 0.86025467, 0.75937783,
#        0.87540873, 0.65446622, 0.64444427, 0.65300668, 0.63499679,
#        0.65893255, 0.84672537, 0.47154187, 0.57804303, 0.62827828,
#        0.73049321, 0.78059085, 0.67873542, 0.74532952, 0.69760164,
#        0.69334456, 0.91721605, 0.65784841, 0.7040523 , 0.72871618,
#        0.51205993, 0.81281386, 0.59660708, 0.79112587, 0.62717226,
#        0.88614781, 0.90117738, 0.92526009, 0.70753139, 0.94179984,
#        0.93837577, 0.58784583, 0.64327008, 0.7320228 , 0.75576686,
#        0.90900708, 0.68002533, 0.66868921, 0.95726963, 0.66060982,
#        0.70339372, 0.59809135, 0.71692302, 0.78210983, 0.93800666,
#        0.64838503, 0.95748923, 0.81654841, 0.500751  , 0.6985591 ,
#        0.85434922, 0.5243278 , 0.52503743, 0.79221544, 0.57001256,
#        0.54047738, 0.60988431, 0.56256648, 0.56804478, 0.82289821,
#        0.70808057, 0.63094262, 0.67399609, 0.83086674, 0.93824948,
#        0.55713016, 0.7942098 , 0.59717749, 0.69271991, 0.73569153])

# %% [markdown]
# ## **Test the model**

# %%
y_test
# Out:
# 261    0.71
# 393    0.77
# 378    0.56
# 185    0.89
# 202    0.97
#        ...
# 22     0.94
# 336    0.72
# 331    0.73
# 131    0.77
# 346    0.47
# Name: Admit_Chance, Length: 120, dtype: float64

# %%
pred=model.predict(X_test)
pred
# Out:
# array([0.64182539, 0.70057065, 0.51585251, 0.85358899, 1.00291653,
#        0.68344689, 0.52633498, 0.906153  , 0.61649864, 0.69240032,
#        0.8066518 , 0.82814133, 0.8526607 , 0.51685069, 0.79607126,
#        0.89223129, 0.42454768, 0.59840934, 0.78578042, 0.85102553,
#        0.64837961, 0.64256465, 0.53585668, 0.76858043, 0.81264379,
#        0.65477421, 0.59230523, 0.78487997, 0.83702783, 0.8905505 ,
#        0.79309509, 0.64625988, 0.67815511, 0.95897208, 0.7822816 ,
#        0.9248204 , 0.49810013, 0.88990905, 0.63235223, 0.73873939,
#        0.8099707 , 0.83067794, 0.50112993, 0.73254272, 0.60990544,
#        0.64642961, 0.64600545, 0.64156851, 0.71725068, 0.53634219,
#        0.75260547, 0.75568351, 0.78800495, 0.56257482, 0.53046194,
#        0.69684683, 0.5927908 , 0.70799788, 0.57796091, 0.72100875,
#        0.58206143, 0.81065998, 0.5902722 , 0.63937017, 0.47977095,
#        0.85473444, 0.82969968, 0.80616266, 0.70732933, 0.6711038 ,
#        0.64146142, 0.56310194, 0.85648829, 0.78613005, 0.78947132,
#        0.70191163, 0.94180558, 0.656858  , 0.75332828, 0.72987191,
#        0.5232856 , 0.89438261, 0.50120868, 0.84189218, 0.63880228,
#        0.78841169, 0.90254082, 0.63483251, 0.59556908, 0.65763799,
#        0.60884497, 0.76917429, 0.6302897 , 0.74277838, 0.97037682,
#        0.8536867 , 0.71302818, 0.77356173, 0.70828165, 0.62614425,
#        0.72102397, 0.85621568, 0.8152879 , 0.95002382, 0.65552532,
#        0.65889673, 0.68309618, 0.67680069, 0.42016447, 0.80720577,
#        0.67612627, 0.94998954, 0.635633  , 0.92066056, 0.4391868 ,
#        0.92232329, 0.72411284, 0.6215881 , 0.69614049, 0.51565612])

# %%
admit_chance_pred = pd.DataFrame({'Actual_value':y_test,'Predicted_value_using_r':pred})
admit_chance_pred.head()
# Out:
#      Actual_value  Predicted_value_using_r
# 261          0.71                 0.641825
# 393          0.77                 0.700571
# 378          0.56                 0.515853
# 185          0.89                 0.853589
# 202          0.97                 1.002917

# %% [markdown]
# ## **Measure the performance using metrics**

# %%
from sklearn import metrics

# %%
# R2-square for Testing Accuracy
print(metrics.r2_score(y_test,pred))
# Out:
# 0.7970727383280378

# %%
# R2-square for Training Accuracy
print(metrics.r2_score(y_train,pred_train))
# Out:
# 0.802562940404405

# %%
# MSE(Mean square error)
print(metrics.mean_squared_error(y_test,pred))
# Out:
# 0.004000322019944528

# %%
# RMSE
print(np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# 0.0632480989433242

# %%
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
